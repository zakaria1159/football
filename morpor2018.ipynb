# %% [markdown]
# <a href="https://colab.research.google.com/github/zakaria1159/football/blob/master/morpor2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

# %% [markdown]
# https://github.com/statsbomb/open-data/archive/refs/heads/master.zip

# %%
# !wget --no-check-certificate \
    "https://github.com/statsbomb/open-data/archive/refs/heads/master.zip" \
    -O "/tmp/world-cup-morocco.zip"


zip_ref = zipfile.ZipFile('/tmp/world-cup-morocco.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()
# Out:
# --2022-04-16 13:05:52--  https://github.com/statsbomb/open-data/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/statsbomb/open-data/zip/refs/heads/master [following]
# --2022-04-16 13:05:52--  https://codeload.github.com/statsbomb/open-data/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/world-cup-morocco.zip’
#
# /tmp/world-cup-moro     [     <=>            ] 346.61M  5.66MB/s    in 72s
#
# 2022-04-16 13:07:04 (4.84 MB/s) - ‘/tmp/world-cup-morocco.zip’ saved [363442445]

# %%
import pandas as pd

competition = pd.read_json('/tmp/open-data-master/data/competitions.json')

competition.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 1   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None     2021-07-09T14:06:05.802
# 1                None  2021-01-23T21:55:30.425330
# 2                None            2020-07-29T05:00
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
competition[competition.competition_name == 'FIFA World Cup']
# Out:
#     competition_id  season_id   country_name competition_name  \
# 18              43          3  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 18               male              False                       True
#
#    season_name               match_updated        match_updated_360  \
# 18        2018  2021-12-06T23:11:59.985953  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 18                None  2021-12-06T23:11:59.985953

# %%
import json

with open('/tmp/open-data-master/data/matches/43/3.json') as f:
    data = json.load(f)

data
# Out:
# [{'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group A',
#    'away_team_id': 783,
#    'away_team_name': 'Uruguay',
#    'country': {'id': 242, 'name': 'Uruguay'},
#    'managers': [{'country': {'id': 242, 'name': 'Uruguay'},
#      'dob': '1947-03-03',
#      'id': 476,
#      'name': 'Óscar Washington Tabárez Silva',
#      'nickname': 'Óscar Tabárez'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 66, 'name': 'Egypt'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group A',
#    'home_team_id': 774,
#    'home_team_name': 'Egypt',
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1955-11-16',
#      'id': 486,
#      'name': 'Héctor Raúl Cúper',
#      'nickname': 'Héctor Cúper'}]},
#   'kick_off': '14:00:00.000',
#   'last_updated': '2021-12-06T22:24:47.980215',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-15',
#   'match_id': 7578,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 160, 'name': 'Netherlands'},
#    'id': 287,
#    'name': 'Björn Kuipers'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4261,
#    'name': 'Ekaterinburg Arena'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group F',
#    'away_team_id': 794,
#    'away_team_name': 'Mexico',
#    'country': {'id': 147, 'name': 'Mexico'},
#    'managers': [{'country': {'id': 49, 'name': 'Colombia'},
#      'dob': '1961-06-08',
#      'id': 632,
#      'name': 'Juan Carlos Osorio Arbeláez',
#      'nickname': 'Juan Carlos Osorio'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group F',
#    'home_team_id': 791,
#    'home_team_name': 'South Korea',
#    'managers': [{'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#      'dob': '1970-10-11',
#      'id': 631,
#      'name': 'Tae-Yong Shin',
#      'nickname': 'Shin Tae-Yong'}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2021-12-06T23:00:56.479071',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-23',
#   'match_id': 7553,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 203, 'name': 'Serbia'},
#    'id': 727,
#    'name': 'Milorad Mažić'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 256,
#    'name': 'Rostov Arena'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group A',
#    'away_team_id': 799,
#    'away_team_name': 'Saudi Arabia',
#    'country': {'id': 200, 'name': 'Saudi Arabia'},
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1968-06-07',
#      'id': 638,
#      'name': 'Juan Antonio Pizzi Torroja',
#      'nickname': 'Pizzi'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 242, 'name': 'Uruguay'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group A',
#    'home_team_id': 783,
#    'home_team_name': 'Uruguay',
#    'managers': [{'country': {'id': 242, 'name': 'Uruguay'},
#      'dob': '1947-03-03',
#      'id': 476,
#      'name': 'Óscar Washington Tabárez Silva',
#      'nickname': 'Óscar Tabárez'}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2021-12-06T22:50:22.229925',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-20',
#   'match_id': 7544,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 78, 'name': 'France'},
#    'id': 76,
#    'name': 'Clément Turpin'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 256,
#    'name': 'Rostov Arena'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group G',
#    'away_team_id': 798,
#    'away_team_name': 'Panama',
#    'country': {'id': 176, 'name': 'Panama'},
#    'managers': [{'country': {'id': 49, 'name': 'Colombia'},
#      'dob': '1956-02-03',
#      'id': 654,
#      'name': 'Hernán Darío Gómez Jaramillo',
#      'nickname': 'Hernán Darío Gómez'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 3,
#   'home_team': {'country': {'id': 22, 'name': 'Belgium'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group G',
#    'home_team_id': 782,
#    'home_team_name': 'Belgium',
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1973-07-13',
#      'id': 263,
#      'name': 'Roberto Martínez Montoliú',
#      'nickname': 'Roberto Martínez'}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2021-12-06T22:40:10.487423',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-18',
#   'match_id': 7536,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 253, 'name': 'Zambia'},
#    'id': 743,
#    'name': 'Janny Sikazwe'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 249,
#    'name': 'Olimpiyskiy Stadion Fisht'}},
#  {'away_score': 3,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group H',
#    'away_team_id': 769,
#    'away_team_name': 'Colombia',
#    'country': {'id': 49, 'name': 'Colombia'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1949-09-03',
#      'id': 634,
#      'name': 'José Néstor Pekerman',
#      'nickname': 'José Pékerman'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 182, 'name': 'Poland'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group H',
#    'home_team_id': 789,
#    'home_team_name': 'Poland',
#    'managers': [{'country': {'id': 182, 'name': 'Poland'},
#      'dob': '1957-10-23',
#      'id': 542,
#      'name': 'Adam Nawałka',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2021-12-06T23:06:14.060164',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-24',
#   'match_id': 7555,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 147, 'name': 'Mexico'},
#    'id': 740,
#    'name': 'César Arturo Ramos Palazuelos'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4258,
#    'name': "Kazan'' Arena"}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group C',
#    'away_team_id': 784,
#    'away_team_name': 'Peru',
#    'country': {'id': 179, 'name': 'Peru'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1958-02-10',
#      'id': 629,
#      'name': 'Ricardo Alberto Gareca Nardi',
#      'nickname': 'Ricardo Gareca'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 78, 'name': 'France'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group C',
#    'home_team_id': 771,
#    'home_team_name': 'France',
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
#      'id': 545,
#      'name': 'Didier Deschamps',
#      'nickname': None}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2021-12-06T22:55:38.505927',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-21',
#   'match_id': 7546,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 239, 'name': 'United Arab Emirates'},
#    'id': 737,
#    'name': 'Mohamed Abdulla Hassan Mohd'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4261,
#    'name': 'Ekaterinburg Arena'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group H',
#    'away_team_id': 787,
#    'away_team_name': 'Senegal',
#    'country': {'id': 202, 'name': 'Senegal'},
#    'managers': [{'country': {'id': 202, 'name': 'Senegal'},
#      'dob': '1976-03-24',
#      'id': 635,
#      'name': 'Aliou Cissé',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 182, 'name': 'Poland'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group H',
#    'home_team_id': 789,
#    'home_team_name': 'Poland',
#    'managers': [{'country': {'id': 182, 'name': 'Poland'},
#      'dob': '1957-10-23',
#      'id': 542,
#      'name': 'Adam Nawałka',
#      'nickname': None}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2021-12-06T22:44:53.797846',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-19',
#   'match_id': 7539,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 18, 'name': 'Bahrain'},
#    'id': 176,
#    'name': 'Nawaf Abdulla Ghayyath Shukralla'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4130,
#    'name': 'Otkrytiye Arena (Moskva)'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group F',
#    'away_team_id': 791,
#    'away_team_name': 'South Korea',
#    'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#    'managers': [{'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#      'dob': '1970-10-11',
#      'id': 631,
#      'name': 'Tae-Yong Shin',
#      'nickname': 'Shin Tae-Yong'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 220, 'name': 'Sweden'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group F',
#    'home_team_id': 790,
#    'home_team_name': 'Sweden',
#    'managers': [{'country': {'id': 220, 'name': 'Sweden'},
#      'dob': '1962-09-29',
#      'id': 549,
#      'name': 'Jan Olof Andersson',
#      'nickname': None}]},
#   'kick_off': '14:00:00.000',
#   'last_updated': '2021-12-06T22:35:05.661789',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-18',
#   'match_id': 7538,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 67, 'name': 'El Salvador'},
#    'id': 742,
#    'name': 'Joel Antonio Aguilar Chicas'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4263,
#    'name': 'Stadion Nizhny Novgorod'}},
#  {'away_score': 3,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group B',
#    'away_team_id': 772,
#    'away_team_name': 'Spain',
#    'country': {'id': 214, 'name': 'Spain'},
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1968-03-23',
#      'id': 643,
#      'name': 'Fernando Ruiz Hierro',
#      'nickname': 'Fernando Hierro'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 3,
#   'home_team': {'country': {'id': 183, 'name': 'Portugal'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group B',
#    'home_team_id': 780,
#    'home_team_name': 'Portugal',
#    'managers': [{'country': {'id': 183, 'name': 'Portugal'},
#      'dob': '1954-10-10',
#      'id': 607,
#      'name': 'Fernando Manuel Fernandes da Costa Santos',
#      'nickname': 'Fernando Santos'}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2021-12-06T22:30:32.372616',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-15',
#   'match_id': 7576,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 112, 'name': 'Italy'},
#    'id': 268,
#    'name': 'Gianluca Rocchi'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 249,
#    'name': 'Olimpiyskiy Stadion Fisht'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group E',
#    'away_team_id': 781,
#    'away_team_name': 'Brazil',
#    'country': {'id': 31, 'name': 'Brazil'},
#    'managers': [{'country': {'id': 31, 'name': 'Brazil'},
#      'dob': '1961-05-25',
#      'id': 547,
#      'name': 'Adenor Leonardo Bacchi',
#      'nickname': 'Tite'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 203, 'name': 'Serbia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group E',
#    'home_team_id': 786,
#    'home_team_name': 'Serbia',
#    'managers': [{'country': {'id': 203, 'name': 'Serbia'},
#      'dob': '1974-03-04',
#      'id': 640,
#      'name': 'Mladen Krstajić',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2021-12-06T23:11:59.985953',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-27',
#   'match_id': 7565,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 107, 'name': 'Iran, Islamic Republic of'},
#    'id': 741,
#    'name': 'Alireza Faghani'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4130,
#    'name': 'Otkrytiye Arena (Moskva)'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group F',
#    'away_team_id': 790,
#    'away_team_name': 'Sweden',
#    'country': {'id': 220, 'name': 'Sweden'},
#    'managers': [{'country': {'id': 220, 'name': 'Sweden'},
#      'dob': '1962-09-29',
#      'id': 549,
#      'name': 'Jan Olof Andersson',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 85, 'name': 'Germany'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group F',
#    'home_team_id': 770,
#    'home_team_name': 'Germany',
#    'managers': [{'country': {'id': 85, 'name': 'Germany'},
#      'dob': '1960-02-03',
#      'id': 602,
#      'name': 'Joachim Löw',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-23',
#   'match_id': 7551,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 182, 'name': 'Poland'},
#    'id': 367,
#    'name': 'Szymon Marciniak'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 249,
#    'name': 'Olimpiyskiy Stadion Fisht'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group E',
#    'away_team_id': 773,
#    'away_team_name': 'Switzerland',
#    'country': {'id': 221, 'name': 'Switzerland'},
#    'managers': [{'country': {'id': 28, 'name': 'Bosnia and Herzegovina'},
#      'dob': '1963-08-15',
#      'id': 492,
#      'name': 'Vladimir Petković',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 203, 'name': 'Serbia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group E',
#    'home_team_id': 786,
#    'home_team_name': 'Serbia',
#    'managers': [{'country': {'id': 203, 'name': 'Serbia'},
#      'dob': '1974-03-04',
#      'id': 640,
#      'name': 'Mladen Krstajić',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-22',
#   'match_id': 7550,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 85, 'name': 'Germany'},
#    'id': 186,
#    'name': 'Felix Brych'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4260,
#    'name': 'Stadion Kaliningrad'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group G',
#    'away_team_id': 768,
#    'away_team_name': 'England',
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'country': {'id': 68, 'name': 'England'},
#      'dob': '1970-09-03',
#      'id': 277,
#      'name': 'Gareth Southgate',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 232, 'name': 'Tunisia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group G',
#    'home_team_id': 777,
#    'home_team_name': 'Tunisia',
#    'managers': [{'country': {'id': 232, 'name': 'Tunisia'},
#      'dob': '1962-07-25',
#      'id': 557,
#      'name': 'Nabil Maâloul',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-18',
#   'match_id': 7537,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 49, 'name': 'Colombia'},
#    'id': 175,
#    'name': 'Wilmar Alexander Roldán Pérez'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4257,
#    'name': 'Volgograd Arena'}},
#  {'away_score': 3,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 779,
#    'away_team_name': 'Argentina',
#    'country': {'id': 11, 'name': 'Argentina'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1960-03-13',
#      'id': 637,
#      'name': 'Jorge Luis Sampaoli Moya',
#      'nickname': 'Jorge Sampaoli'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'home_score': 4,
#   'home_team': {'country': {'id': 78, 'name': 'France'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 771,
#    'home_team_name': 'France',
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
#      'id': 545,
#      'name': 'Didier Deschamps',
#      'nickname': None}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-30',
#   'match_id': 7580,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 4,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 107, 'name': 'Iran, Islamic Republic of'},
#    'id': 741,
#    'name': 'Alireza Faghani'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4258,
#    'name': "Kazan'' Arena"}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 782,
#    'away_team_name': 'Belgium',
#    'country': {'id': 22, 'name': 'Belgium'},
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1973-07-13',
#      'id': 263,
#      'name': 'Roberto Martínez Montoliú',
#      'nickname': 'Roberto Martínez'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 31, 'name': 'Brazil'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 781,
#    'home_team_name': 'Brazil',
#    'managers': [{'country': {'id': 31, 'name': 'Brazil'},
#      'dob': '1961-05-25',
#      'id': 547,
#      'name': 'Adenor Leonardo Bacchi',
#      'nickname': 'Tite'}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-06',
#   'match_id': 8650,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 5,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 203, 'name': 'Serbia'},
#    'id': 727,
#    'name': 'Milorad Mažić'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4258,
#    'name': "Kazan'' Arena"}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 776,
#    'away_team_name': 'Denmark',
#    'country': {'id': 61, 'name': 'Denmark'},
#    'managers': [{'country': {'id': 171, 'name': 'Norway'},
#      'dob': '1953-09-23',
#      'id': 641,
#      'name': 'Åge Fridtjof Hareide',
#      'nickname': 'Åge Hareide'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 56, 'name': 'Croatia'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 785,
#    'home_team_name': 'Croatia',
#    'managers': [{'country': {'id': 56, 'name': 'Croatia'},
#      'dob': '1966-10-26',
#      'id': 307,
#      'name': 'Zlatko Dalić',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-01',
#   'match_id': 7581,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 4,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 11, 'name': 'Argentina'},
#    'id': 730,
#    'name': 'Néstor Fabián Pitana'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4263,
#    'name': 'Stadion Nizhny Novgorod'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group D',
#    'away_team_id': 793,
#    'away_team_name': 'Iceland',
#    'country': {'id': 104, 'name': 'Iceland'},
#    'managers': [{'country': {'id': 104, 'name': 'Iceland'},
#      'dob': '1967-06-10',
#      'id': 648,
#      'name': 'Heimir Hallgrímsson',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 166, 'name': 'Nigeria'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group D',
#    'home_team_id': 775,
#    'home_team_name': 'Nigeria',
#    'managers': [{'country': {'id': 85, 'name': 'Germany'},
#      'dob': '1953-06-28',
#      'id': 636,
#      'name': 'Gernot Rohr',
#      'nickname': None}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-22',
#   'match_id': 7549,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 163, 'name': 'New Zealand'},
#    'id': 739,
#    'name': 'Matthew Conger'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4257,
#    'name': 'Volgograd Arena'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group D',
#    'away_team_id': 775,
#    'away_team_name': 'Nigeria',
#    'country': {'id': 166, 'name': 'Nigeria'},
#    'managers': [{'country': {'id': 85, 'name': 'Germany'},
#      'dob': '1953-06-28',
#      'id': 636,
#      'name': 'Gernot Rohr',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 56, 'name': 'Croatia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group D',
#    'home_team_id': 785,
#    'home_team_name': 'Croatia',
#    'managers': [{'country': {'id': 56, 'name': 'Croatia'},
#      'dob': '1966-10-26',
#      'id': 307,
#      'name': 'Zlatko Dalić',
#      'nickname': None}]},
#   'kick_off': '21:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-16',
#   'match_id': 7529,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 31, 'name': 'Brazil'},
#    'id': 738,
#    'name': 'Sandro Ricci'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4260,
#    'name': 'Stadion Kaliningrad'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group E',
#    'away_team_id': 795,
#    'away_team_name': 'Costa Rica',
#    'country': {'id': 54, 'name': 'Costa Rica'},
#    'managers': [{'country': {'id': 54, 'name': 'Costa Rica'},
#      'dob': '1964-12-08',
#      'id': 646,
#      'name': 'Óscar Antonio Ramírez Hernández',
#      'nickname': 'Óscar Ramírez'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 31, 'name': 'Brazil'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group E',
#    'home_team_id': 781,
#    'home_team_name': 'Brazil',
#    'managers': [{'country': {'id': 31, 'name': 'Brazil'},
#      'dob': '1961-05-25',
#      'id': 547,
#      'name': 'Adenor Leonardo Bacchi',
#      'nickname': 'Tite'}]},
#   'kick_off': '14:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-22',
#   'match_id': 7548,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 160, 'name': 'Netherlands'},
#    'id': 287,
#    'name': 'Björn Kuipers'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4726,
#    'name': 'Saint-Petersburg Stadium'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group F',
#    'away_team_id': 794,
#    'away_team_name': 'Mexico',
#    'country': {'id': 147, 'name': 'Mexico'},
#    'managers': [{'country': {'id': 49, 'name': 'Colombia'},
#      'dob': '1961-06-08',
#      'id': 632,
#      'name': 'Juan Carlos Osorio Arbeláez',
#      'nickname': 'Juan Carlos Osorio'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 85, 'name': 'Germany'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group F',
#    'home_team_id': 770,
#    'home_team_name': 'Germany',
#    'managers': [{'country': {'id': 85, 'name': 'Germany'},
#      'dob': '1960-02-03',
#      'id': 602,
#      'name': 'Joachim Löw',
#      'nickname': None}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-17',
#   'match_id': 7534,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 107, 'name': 'Iran, Islamic Republic of'},
#    'id': 741,
#    'name': 'Alireza Faghani'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 255,
#    'name': 'Stadion Luzhniki'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group C',
#    'away_team_id': 784,
#    'away_team_name': 'Peru',
#    'country': {'id': 179, 'name': 'Peru'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1958-02-10',
#      'id': 629,
#      'name': 'Ricardo Alberto Gareca Nardi',
#      'nickname': 'Ricardo Gareca'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 14, 'name': 'Australia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group C',
#    'home_team_id': 792,
#    'home_team_name': 'Australia',
#    'managers': [{'country': {'id': 160, 'name': 'Netherlands'},
#      'dob': '1952-05-19',
#      'id': 630,
#      'name': 'Lambertus van Marwijk',
#      'nickname': None}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-26',
#   'match_id': 7562,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 725,
#    'name': 'Sergey Karasev'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 249,
#    'name': 'Olimpiyskiy Stadion Fisht'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group H',
#    'away_team_id': 769,
#    'away_team_name': 'Colombia',
#    'country': {'id': 49, 'name': 'Colombia'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1949-09-03',
#      'id': 634,
#      'name': 'José Néstor Pekerman',
#      'nickname': 'José Pékerman'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 202, 'name': 'Senegal'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group H',
#    'home_team_id': 787,
#    'home_team_name': 'Senegal',
#    'managers': [{'country': {'id': 202, 'name': 'Senegal'},
#      'dob': '1976-03-24',
#      'id': 635,
#      'name': 'Aliou Cissé',
#      'nickname': None}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-28',
#   'match_id': 7571,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 203, 'name': 'Serbia'},
#    'id': 727,
#    'name': 'Milorad Mažić'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 118023,
#    'name': 'Solidarnost Arena'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group G',
#    'away_team_id': 777,
#    'away_team_name': 'Tunisia',
#    'country': {'id': 232, 'name': 'Tunisia'},
#    'managers': [{'country': {'id': 232, 'name': 'Tunisia'},
#      'dob': '1962-07-25',
#      'id': 557,
#      'name': 'Nabil Maâloul',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 176, 'name': 'Panama'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group G',
#    'home_team_id': 798,
#    'home_team_name': 'Panama',
#    'managers': [{'country': {'id': 49, 'name': 'Colombia'},
#      'dob': '1956-02-03',
#      'id': 654,
#      'name': 'Hernán Darío Gómez Jaramillo',
#      'nickname': 'Hernán Darío Gómez'}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-28',
#   'match_id': 7569,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 18, 'name': 'Bahrain'},
#    'id': 176,
#    'name': 'Nawaf Abdulla Ghayyath Shukralla'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4259,
#    'name': 'Mordovia Arena'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group E',
#    'away_team_id': 795,
#    'away_team_name': 'Costa Rica',
#    'country': {'id': 54, 'name': 'Costa Rica'},
#    'managers': [{'country': {'id': 54, 'name': 'Costa Rica'},
#      'dob': '1964-12-08',
#      'id': 646,
#      'name': 'Óscar Antonio Ramírez Hernández',
#      'nickname': 'Óscar Ramírez'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 221, 'name': 'Switzerland'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group E',
#    'home_team_id': 773,
#    'home_team_name': 'Switzerland',
#    'managers': [{'country': {'id': 28, 'name': 'Bosnia and Herzegovina'},
#      'dob': '1963-08-15',
#      'id': 492,
#      'name': 'Vladimir Petković',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-27',
#   'match_id': 7568,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 78, 'name': 'France'},
#    'id': 76,
#    'name': 'Clément Turpin'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4263,
#    'name': 'Stadion Nizhny Novgorod'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group C',
#    'away_team_id': 792,
#    'away_team_name': 'Australia',
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'country': {'id': 160, 'name': 'Netherlands'},
#      'dob': '1952-05-19',
#      'id': 630,
#      'name': 'Lambertus van Marwijk',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 78, 'name': 'France'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group C',
#    'home_team_id': 771,
#    'home_team_name': 'France',
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
#      'id': 545,
#      'name': 'Didier Deschamps',
#      'nickname': None}]},
#   'kick_off': '12:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-16',
#   'match_id': 7530,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 242, 'name': 'Uruguay'},
#    'id': 734,
#    'name': 'Andrés Cunha'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4258,
#    'name': "Kazan'' Arena"}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group A',
#    'away_team_id': 796,
#    'away_team_name': 'Russia',
#    'country': {'id': 188, 'name': 'Russia'},
#    'managers': [{'country': {'id': 188, 'name': 'Russia'},
#      'dob': '1963-09-02',
#      'id': 365,
#      'name': 'Stanislav Cherchesov',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 3,
#   'home_team': {'country': {'id': 242, 'name': 'Uruguay'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group A',
#    'home_team_id': 783,
#    'home_team_name': 'Uruguay',
#    'managers': [{'country': {'id': 242, 'name': 'Uruguay'},
#      'dob': '1947-03-03',
#      'id': 476,
#      'name': 'Óscar Washington Tabárez Silva',
#      'nickname': 'Óscar Tabárez'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-10-25T14:03:50.263266',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-25',
#   'match_id': 7558,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 202, 'name': 'Senegal'},
#    'id': 732,
#    'name': 'Malang Diedhiou'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 118023,
#    'name': 'Solidarnost Arena'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 794,
#    'away_team_name': 'Mexico',
#    'country': {'id': 147, 'name': 'Mexico'},
#    'managers': [{'country': {'id': 49, 'name': 'Colombia'},
#      'dob': '1961-06-08',
#      'id': 632,
#      'name': 'Juan Carlos Osorio Arbeláez',
#      'nickname': 'Juan Carlos Osorio'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 31, 'name': 'Brazil'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 781,
#    'home_team_name': 'Brazil',
#    'managers': [{'country': {'id': 31, 'name': 'Brazil'},
#      'dob': '1961-05-25',
#      'id': 547,
#      'name': 'Adenor Leonardo Bacchi',
#      'nickname': 'Tite'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-02',
#   'match_id': 7583,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 4,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 112, 'name': 'Italy'},
#    'id': 268,
#    'name': 'Gianluca Rocchi'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 118023,
#    'name': 'Solidarnost Arena'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group C',
#    'away_team_id': 792,
#    'away_team_name': 'Australia',
#    'country': {'id': 14, 'name': 'Australia'},
#    'managers': [{'country': {'id': 160, 'name': 'Netherlands'},
#      'dob': '1952-05-19',
#      'id': 630,
#      'name': 'Lambertus van Marwijk',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 61, 'name': 'Denmark'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group C',
#    'home_team_id': 776,
#    'home_team_name': 'Denmark',
#    'managers': [{'country': {'id': 171, 'name': 'Norway'},
#      'dob': '1953-09-23',
#      'id': 641,
#      'name': 'Åge Fridtjof Hareide',
#      'nickname': 'Åge Hareide'}]},
#   'kick_off': '14:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-21',
#   'match_id': 7547,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 214, 'name': 'Spain'},
#    'id': 180,
#    'name': 'Antonio Miguel Mateu Lahoz'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 118023,
#    'name': 'Solidarnost Arena'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group E',
#    'away_team_id': 786,
#    'away_team_name': 'Serbia',
#    'country': {'id': 203, 'name': 'Serbia'},
#    'managers': [{'country': {'id': 203, 'name': 'Serbia'},
#      'dob': '1974-03-04',
#      'id': 640,
#      'name': 'Mladen Krstajić',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 54, 'name': 'Costa Rica'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group E',
#    'home_team_id': 795,
#    'home_team_name': 'Costa Rica',
#    'managers': [{'country': {'id': 54, 'name': 'Costa Rica'},
#      'dob': '1964-12-08',
#      'id': 646,
#      'name': 'Óscar Antonio Ramírez Hernández',
#      'nickname': 'Óscar Ramírez'}]},
#   'kick_off': '14:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-17',
#   'match_id': 7535,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 202, 'name': 'Senegal'},
#    'id': 732,
#    'name': 'Malang Diedhiou'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 118023,
#    'name': 'Solidarnost Arena'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 778,
#    'away_team_name': 'Japan',
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'country': {'id': 114, 'name': 'Japan'},
#      'dob': '1955-04-07',
#      'id': 644,
#      'name': 'Akira Nishino',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 33, 'name': 'Round of 16'},
#   'home_score': 3,
#   'home_team': {'country': {'id': 22, 'name': 'Belgium'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 782,
#    'home_team_name': 'Belgium',
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1973-07-13',
#      'id': 263,
#      'name': 'Roberto Martínez Montoliú',
#      'nickname': 'Roberto Martínez'}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-02',
#   'match_id': 7584,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 4,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 202, 'name': 'Senegal'},
#    'id': 732,
#    'name': 'Malang Diedhiou'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 256,
#    'name': 'Rostov Arena'}},
#  {'away_score': 3,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group D',
#    'away_team_id': 785,
#    'away_team_name': 'Croatia',
#    'country': {'id': 56, 'name': 'Croatia'},
#    'managers': [{'country': {'id': 56, 'name': 'Croatia'},
#      'dob': '1966-10-26',
#      'id': 307,
#      'name': 'Zlatko Dalić',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 11, 'name': 'Argentina'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group D',
#    'home_team_id': 779,
#    'home_team_name': 'Argentina',
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1960-03-13',
#      'id': 637,
#      'name': 'Jorge Luis Sampaoli Moya',
#      'nickname': 'Jorge Sampaoli'}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-21',
#   'match_id': 7545,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 244, 'name': 'Uzbekistan'},
#    'id': 735,
#    'name': 'Ravshan Irmatov'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4263,
#    'name': 'Stadion Nizhny Novgorod'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 771,
#    'away_team_name': 'France',
#    'country': {'id': 78, 'name': 'France'},
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
#      'id': 545,
#      'name': 'Didier Deschamps',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 242, 'name': 'Uruguay'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 783,
#    'home_team_name': 'Uruguay',
#    'managers': [{'country': {'id': 242, 'name': 'Uruguay'},
#      'dob': '1947-03-03',
#      'id': 476,
#      'name': 'Óscar Washington Tabárez Silva',
#      'nickname': 'Óscar Tabárez'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-06',
#   'match_id': 8649,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 5,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 11, 'name': 'Argentina'},
#    'id': 730,
#    'name': 'Néstor Fabián Pitana'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4263,
#    'name': 'Stadion Nizhny Novgorod'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 785,
#    'away_team_name': 'Croatia',
#    'country': {'id': 56, 'name': 'Croatia'},
#    'managers': [{'country': {'id': 56, 'name': 'Croatia'},
#      'dob': '1966-10-26',
#      'id': 307,
#      'name': 'Zlatko Dalić',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 26, 'name': 'Final'},
#   'home_score': 4,
#   'home_team': {'country': {'id': 78, 'name': 'France'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 771,
#    'home_team_name': 'France',
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
# ...
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 768,
#    'away_team_name': 'England',
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'country': {'id': 68, 'name': 'England'},
#      'dob': '1970-09-03',
#      'id': 277,
#      'name': 'Gareth Southgate',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 15, 'name': 'Semi-finals'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 56, 'name': 'Croatia'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 785,
#    'home_team_name': 'Croatia',
#    'managers': [{'country': {'id': 56, 'name': 'Croatia'},
#      'dob': '1966-10-26',
#      'id': 307,
#      'name': 'Zlatko Dalić',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-11',
#   'match_id': 8656,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 6,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 233, 'name': 'Turkey'},
#    'id': 581,
#    'name': 'Cüneyt Çakιr'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 255,
#    'name': 'Stadion Luzhniki'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 768,
#    'away_team_name': 'England',
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'country': {'id': 68, 'name': 'England'},
#      'dob': '1970-09-03',
#      'id': 277,
#      'name': 'Gareth Southgate',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 220, 'name': 'Sweden'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 790,
#    'home_team_name': 'Sweden',
#    'managers': [{'country': {'id': 220, 'name': 'Sweden'},
#      'dob': '1962-09-29',
#      'id': 549,
#      'name': 'Jan Olof Andersson',
#      'nickname': None}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-07',
#   'match_id': 8651,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 5,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 160, 'name': 'Netherlands'},
#    'id': 287,
#    'name': 'Björn Kuipers'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 118023,
#    'name': 'Solidarnost Arena'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group F',
#    'away_team_id': 770,
#    'away_team_name': 'Germany',
#    'country': {'id': 85, 'name': 'Germany'},
#    'managers': [{'country': {'id': 85, 'name': 'Germany'},
#      'dob': '1960-02-03',
#      'id': 602,
#      'name': 'Joachim Löw',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group F',
#    'home_team_id': 791,
#    'home_team_name': 'South Korea',
#    'managers': [{'country': {'id': 121, 'name': 'Korea\xa0(South)'},
#      'dob': '1970-10-11',
#      'id': 631,
#      'name': 'Tae-Yong Shin',
#      'nickname': 'Shin Tae-Yong'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-27',
#   'match_id': 7567,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 241, 'name': 'United States of America'},
#    'id': 435,
#    'name': 'Mark Geiger'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4258,
#    'name': "Kazan'' Arena"}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group H',
#    'away_team_id': 778,
#    'away_team_name': 'Japan',
#    'country': {'id': 114, 'name': 'Japan'},
#    'managers': [{'country': {'id': 114, 'name': 'Japan'},
#      'dob': '1955-04-07',
#      'id': 644,
#      'name': 'Akira Nishino',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 49, 'name': 'Colombia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group H',
#    'home_team_id': 769,
#    'home_team_name': 'Colombia',
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1949-09-03',
#      'id': 634,
#      'name': 'José Néstor Pekerman',
#      'nickname': 'José Pékerman'}]},
#   'kick_off': '14:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-19',
#   'match_id': 7541,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 1,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 208, 'name': 'Slovenia'},
#    'id': 420,
#    'name': 'Damir Skomina'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4259,
#    'name': 'Mordovia Arena'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 782,
#    'away_team_name': 'Belgium',
#    'country': {'id': 22, 'name': 'Belgium'},
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1973-07-13',
#      'id': 263,
#      'name': 'Roberto Martínez Montoliú',
#      'nickname': 'Roberto Martínez'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 15, 'name': 'Semi-finals'},
#   'home_score': 1,
#   'home_team': {'country': {'id': 78, 'name': 'France'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 771,
#    'home_team_name': 'France',
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
#      'id': 545,
#      'name': 'Didier Deschamps',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-10',
#   'match_id': 8655,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 6,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 242, 'name': 'Uruguay'},
#    'id': 734,
#    'name': 'Andrés Cunha'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4726,
#    'name': 'Saint-Petersburg Stadium'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 768,
#    'away_team_name': 'England',
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'country': {'id': 68, 'name': 'England'},
#      'dob': '1970-09-03',
#      'id': 277,
#      'name': 'Gareth Southgate',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 25, 'name': '3rd Place Final'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 22, 'name': 'Belgium'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 782,
#    'home_team_name': 'Belgium',
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1973-07-13',
#      'id': 263,
#      'name': 'Roberto Martínez Montoliú',
#      'nickname': 'Roberto Martínez'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-14',
#   'match_id': 8657,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 7,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 107, 'name': 'Iran, Islamic Republic of'},
#    'id': 741,
#    'name': 'Alireza Faghani'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4726,
#    'name': 'Saint-Petersburg Stadium'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group A',
#    'away_team_id': 774,
#    'away_team_name': 'Egypt',
#    'country': {'id': 66, 'name': 'Egypt'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1955-11-16',
#      'id': 486,
#      'name': 'Héctor Raúl Cúper',
#      'nickname': 'Héctor Cúper'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 3,
#   'home_team': {'country': {'id': 188, 'name': 'Russia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group A',
#    'home_team_id': 796,
#    'home_team_name': 'Russia',
#    'managers': [{'country': {'id': 188, 'name': 'Russia'},
#      'dob': '1963-09-02',
#      'id': 365,
#      'name': 'Stanislav Cherchesov',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-19',
#   'match_id': 7540,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 178, 'name': 'Paraguay'},
#    'id': 731,
#    'name': 'Enrique Cáceres'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4726,
#    'name': 'Saint-Petersburg Stadium'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': None,
#    'away_team_id': 785,
#    'away_team_name': 'Croatia',
#    'country': {'id': 56, 'name': 'Croatia'},
#    'managers': [{'country': {'id': 56, 'name': 'Croatia'},
#      'dob': '1966-10-26',
#      'id': 307,
#      'name': 'Zlatko Dalić',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 11, 'name': 'Quarter-finals'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 188, 'name': 'Russia'},
#    'home_team_gender': 'male',
#    'home_team_group': None,
#    'home_team_id': 796,
#    'home_team_name': 'Russia',
#    'managers': [{'country': {'id': 188, 'name': 'Russia'},
#      'dob': '1963-09-02',
#      'id': 365,
#      'name': 'Stanislav Cherchesov',
#      'nickname': None}]},
#   'kick_off': '20:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-07-07',
#   'match_id': 8652,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 5,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 31, 'name': 'Brazil'},
#    'id': 738,
#    'name': 'Sandro Ricci'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 249,
#    'name': 'Olimpiyskiy Stadion Fisht'}},
#  {'away_score': 0,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group C',
#    'away_team_id': 771,
#    'away_team_name': 'France',
#    'country': {'id': 78, 'name': 'France'},
#    'managers': [{'country': {'id': 78, 'name': 'France'},
#      'dob': '1968-10-15',
#      'id': 545,
#      'name': 'Didier Deschamps',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 0,
#   'home_team': {'country': {'id': 61, 'name': 'Denmark'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group C',
#    'home_team_id': 776,
#    'home_team_name': 'Denmark',
#    'managers': [{'country': {'id': 171, 'name': 'Norway'},
#      'dob': '1953-09-23',
#      'id': 641,
#      'name': 'Åge Fridtjof Hareide',
#      'nickname': 'Åge Hareide'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-26',
#   'match_id': 7563,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 31, 'name': 'Brazil'},
#    'id': 738,
#    'name': 'Sandro Ricci'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 255,
#    'name': 'Stadion Luzhniki'}},
#  {'away_score': 2,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group H',
#    'away_team_id': 787,
#    'away_team_name': 'Senegal',
#    'country': {'id': 202, 'name': 'Senegal'},
#    'managers': [{'country': {'id': 202, 'name': 'Senegal'},
#      'dob': '1976-03-24',
#      'id': 635,
#      'name': 'Aliou Cissé',
#      'nickname': None}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 114, 'name': 'Japan'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group H',
#    'home_team_id': 778,
#    'home_team_name': 'Japan',
#    'managers': [{'country': {'id': 114, 'name': 'Japan'},
#      'dob': '1955-04-07',
#      'id': 644,
#      'name': 'Akira Nishino',
#      'nickname': None}]},
#   'kick_off': '17:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-24',
#   'match_id': 7556,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 2,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 112, 'name': 'Italy'},
#    'id': 268,
#    'name': 'Gianluca Rocchi'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4261,
#    'name': 'Ekaterinburg Arena'}},
#  {'away_score': 1,
#   'away_team': {'away_team_gender': 'male',
#    'away_team_group': 'Group A',
#    'away_team_id': 774,
#    'away_team_name': 'Egypt',
#    'country': {'id': 66, 'name': 'Egypt'},
#    'managers': [{'country': {'id': 11, 'name': 'Argentina'},
#      'dob': '1955-11-16',
#      'id': 486,
#      'name': 'Héctor Raúl Cúper',
#      'nickname': 'Héctor Cúper'}]},
#   'competition': {'competition_id': 43,
#    'competition_name': 'FIFA World Cup',
#    'country_name': 'International'},
#   'competition_stage': {'id': 10, 'name': 'Group Stage'},
#   'home_score': 2,
#   'home_team': {'country': {'id': 200, 'name': 'Saudi Arabia'},
#    'home_team_gender': 'male',
#    'home_team_group': 'Group A',
#    'home_team_id': 799,
#    'home_team_name': 'Saudi Arabia',
#    'managers': [{'country': {'id': 214, 'name': 'Spain'},
#      'dob': '1968-06-07',
#      'id': 638,
#      'name': 'Juan Antonio Pizzi Torroja',
#      'nickname': 'Pizzi'}]},
#   'kick_off': '16:00:00.000',
#   'last_updated': '2020-07-29T05:00',
#   'last_updated_360': '2021-06-13T16:17:31.694',
#   'match_date': '2018-06-25',
#   'match_id': 7559,
#   'match_status': 'available',
#   'match_status_360': 'scheduled',
#   'match_week': 3,
#   'metadata': {'data_version': '1.0.2'},
#   'referee': {'country': {'id': 49, 'name': 'Colombia'},
#    'id': 175,
#    'name': 'Wilmar Alexander Roldán Pérez'},
#   'season': {'season_id': 3, 'season_name': '2018'},
#   'stadium': {'country': {'id': 188, 'name': 'Russia'},
#    'id': 4257,
#    'name': 'Volgograd Arena'}}]

# %%
with open('/tmp/open-data-master/data/matches/43/3.json') as f:
    data = json.load(f)
    for i in data:
        print('ID:', i['match_id'], i['home_team']['home_team_name'], i['home_score'], '-', i['away_score'], i['away_team']['away_team_name'])
# Out:
# ID: 7578 Egypt 0 - 1 Uruguay
# ID: 7553 South Korea 1 - 2 Mexico
# ID: 7544 Uruguay 1 - 0 Saudi Arabia
# ID: 7536 Belgium 3 - 0 Panama
# ID: 7555 Poland 0 - 3 Colombia
# ID: 7546 France 1 - 0 Peru
# ID: 7539 Poland 1 - 2 Senegal
# ID: 7538 Sweden 1 - 0 South Korea
# ID: 7576 Portugal 3 - 3 Spain
# ID: 7565 Serbia 0 - 2 Brazil
# ID: 7551 Germany 2 - 1 Sweden
# ID: 7550 Serbia 1 - 2 Switzerland
# ID: 7537 Tunisia 1 - 2 England
# ID: 7580 France 4 - 3 Argentina
# ID: 8650 Brazil 1 - 2 Belgium
# ID: 7581 Croatia 1 - 1 Denmark
# ID: 7549 Nigeria 2 - 0 Iceland
# ID: 7529 Croatia 2 - 0 Nigeria
# ID: 7548 Brazil 2 - 0 Costa Rica
# ID: 7534 Germany 0 - 1 Mexico
# ID: 7562 Australia 0 - 2 Peru
# ID: 7571 Senegal 0 - 1 Colombia
# ID: 7569 Panama 1 - 2 Tunisia
# ID: 7568 Switzerland 2 - 2 Costa Rica
# ID: 7530 France 2 - 1 Australia
# ID: 7558 Uruguay 3 - 0 Russia
# ID: 7583 Brazil 2 - 0 Mexico
# ID: 7547 Denmark 1 - 1 Australia
# ID: 7535 Costa Rica 0 - 1 Serbia
# ID: 7584 Belgium 3 - 2 Japan
# ID: 7545 Argentina 0 - 3 Croatia
# ID: 8649 Uruguay 0 - 2 France
# ID: 8658 France 4 - 2 Croatia
# ID: 7561 Iceland 1 - 2 Croatia
# ID: 7531 Argentina 1 - 1 Iceland
# ID: 7582 Spain 1 - 1 Russia
# ID: 7552 Belgium 5 - 2 Tunisia
# ID: 7532 Peru 0 - 1 Denmark
# ID: 7560 Spain 2 - 2 Morocco
# ID: 7533 Brazil 1 - 1 Switzerland
# ID: 7564 Nigeria 1 - 2 Argentina
# ID: 7579 Uruguay 2 - 1 Portugal
# ID: 7572 Japan 0 - 1 Poland
# ID: 7577 Morocco 0 - 1 Iran
# ID: 7543 Iran 0 - 1 Spain
# ID: 7525 Russia 5 - 0 Saudi Arabia
# ID: 7542 Portugal 1 - 0 Morocco
# ID: 7566 Mexico 0 - 3 Sweden
# ID: 7557 Iran 1 - 1 Portugal
# ID: 7554 England 6 - 1 Panama
# ID: 7570 England 0 - 1 Belgium
# ID: 7585 Colombia 1 - 1 England
# ID: 7586 Sweden 1 - 0 Switzerland
# ID: 8656 Croatia 2 - 1 England
# ID: 8651 Sweden 0 - 2 England
# ID: 7567 South Korea 2 - 0 Germany
# ID: 7541 Colombia 1 - 2 Japan
# ID: 8655 France 1 - 0 Belgium
# ID: 8657 Belgium 2 - 0 England
# ID: 7540 Russia 3 - 1 Egypt
# ID: 8652 Russia 2 - 2 Croatia
# ID: 7563 Denmark 0 - 0 France
# ID: 7556 Japan 2 - 2 Senegal
# ID: 7559 Saudi Arabia 2 - 1 Egypt

# %% [markdown]
# *   ID: 7542 Portugal 1 - 0 Morocco
# *   ID: 7577 Morocco 0 - 1 Iran
# *   ID: 7560 Spain 2 - 2 Morocco

# %%
with open('/tmp/open-data-master/data/events/7542.json') as f:
    morpor = json.load(f)
    
morpor
# Out:
# [{'duration': 2.252,
#   'id': 'c3a01e2d-02fe-4d24-b291-8ed6a6d16d51',
#   'index': 1,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'second': 0,
#   'tactics': {'formation': 442,
#    'lineup': [{'jersey_number': 1,
#      'player': {'id': 5205, 'name': 'Rui Pedro dos Santos Patrício'},
#      'position': {'id': 1, 'name': 'Goalkeeper'}},
#     {'jersey_number': 21,
#      'player': {'id': 3329, 'name': 'Cédric Ricardo Alves Soares'},
#      'position': {'id': 2, 'name': 'Right Back'}},
#     {'jersey_number': 3,
#      'player': {'id': 20016, 'name': 'Kléper Laveran Lima Ferreira'},
#      'position': {'id': 3, 'name': 'Right Center Back'}},
#     {'jersey_number': 6,
#      'player': {'id': 3960, 'name': 'José Miguel da Rocha Fonte'},
#      'position': {'id': 5, 'name': 'Left Center Back'}},
#     {'jersey_number': 5,
#      'player': {'id': 5209, 'name': 'Raphaël Adelino José Guerreiro'},
#      'position': {'id': 6, 'name': 'Left Back'}},
#     {'jersey_number': 11,
#      'player': {'id': 3193, 'name': 'Bernardo Mota Veiga de Carvalho e Silva'},
#      'position': {'id': 12, 'name': 'Right Midfield'}},
#     {'jersey_number': 8,
#      'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'}},
#     {'jersey_number': 14,
#      'player': {'id': 5214, 'name': 'William Silva de Carvalho'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'}},
#     {'jersey_number': 10,
#      'player': {'id': 4272, 'name': 'João Mário Naval da Costa Eduardo'},
#      'position': {'id': 16, 'name': 'Left Midfield'}},
#     {'jersey_number': 17,
#      'player': {'id': 4367, 'name': 'Gonçalo Manuel Ganchinho Guedes'},
#      'position': {'id': 22, 'name': 'Right Center Forward'}},
#     {'jersey_number': 7,
#      'player': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#      'position': {'id': 24, 'name': 'Left Center Forward'}}]},
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 35, 'name': 'Starting XI'}},
#  {'duration': 0.0,
#   'id': 'f6b2184f-73f9-434d-8774-c3b5c77fdd26',
#   'index': 2,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'second': 0,
#   'tactics': {'formation': 4231,
#    'lineup': [{'jersey_number': 12,
#      'player': {'id': 5233, 'name': 'Munir Mohand Mohamedi'},
#      'position': {'id': 1, 'name': 'Goalkeeper'}},
#     {'jersey_number': 17,
#      'player': {'id': 5727, 'name': 'Nabil Dirar'},
#      'position': {'id': 2, 'name': 'Right Back'}},
#     {'jersey_number': 5,
#      'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#      'position': {'id': 3, 'name': 'Right Center Back'}},
#     {'jersey_number': 4,
#      'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#      'position': {'id': 5, 'name': 'Left Center Back'}},
#     {'jersey_number': 2,
#      'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#      'position': {'id': 6, 'name': 'Left Back'}},
#     {'jersey_number': 8,
#      'player': {'id': 5236, 'name': 'Karim El Ahmadi Al Aroos'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'}},
#     {'jersey_number': 14,
#      'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'}},
#     {'jersey_number': 16,
#      'player': {'id': 3302, 'name': 'Nordin Amrabat'},
#      'position': {'id': 17, 'name': 'Right Wing'}},
#     {'jersey_number': 10,
#      'player': {'id': 5242, 'name': 'Younès Belhanda'},
#      'position': {'id': 19, 'name': 'Center Attacking Midfield'}},
#     {'jersey_number': 7,
#      'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#      'position': {'id': 21, 'name': 'Left Wing'}},
#     {'jersey_number': 13,
#      'player': {'id': 5726, 'name': 'Khalid Boutaïb'},
#      'position': {'id': 23, 'name': 'Center Forward'}}]},
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 35, 'name': 'Starting XI'}},
#  {'duration': 7.573,
#   'id': 'cf4ba856-d756-47ec-97b9-32f571b504d1',
#   'index': 3,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['93e265e9-d68c-4ea6-806b-a2719eb9d188'],
#   'second': 0,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 18, 'name': 'Half Start'}},
#  {'duration': 9.12,
#   'id': '93e265e9-d68c-4ea6-806b-a2719eb9d188',
#   'index': 4,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['cf4ba856-d756-47ec-97b9-32f571b504d1'],
#   'second': 0,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 18, 'name': 'Half Start'}},
#  {'duration': 4.4,
#   'id': '1528310a-ada1-4630-9a9a-42b504f00c7b',
#   'index': 5,
#   'location': [65.0, 53.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 1,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['0dae0d7e-f606-4d22-bd46-147259e3922d',
#    '1360fbd8-598c-4790-9ec6-eff2ffba99c0',
#    '685a0e1a-1036-4a2e-9425-6fd9ef7c7f7a',
#    'b423c91e-3519-4a94-920a-1532d185b3cd',
#    'df4ce143-11d3-4664-8287-fa8a1865bf0e',
#    'ea77e2e2-4f78-44bc-b003-d13ccd07b5f7',
#    'f5926997-41d5-486c-89bc-5a9ae4c28dbc'],
#   'second': 0,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:00.100',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 0.56,
#   'id': '0dae0d7e-f606-4d22-bd46-147259e3922d',
#   'index': 6,
#   'location': [60.0, 41.0],
#   'minute': 0,
#   'pass': {'angle': 2.819842,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [45.0, 46.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 15.811388,
#    'recipient': {'id': 5232, 'name': 'Mbark Boussoufa'},
#    'type': {'id': 65, 'name': 'Kick Off'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5726, 'name': 'Khalid Boutaïb'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1528310a-ada1-4630-9a9a-42b504f00c7b',
#    '685a0e1a-1036-4a2e-9425-6fd9ef7c7f7a'],
#   'second': 0,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:00.100',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '685a0e1a-1036-4a2e-9425-6fd9ef7c7f7a',
#   'index': 7,
#   'location': [45.0, 46.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0dae0d7e-f606-4d22-bd46-147259e3922d',
#    '1528310a-ada1-4630-9a9a-42b504f00c7b'],
#   'second': 0,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:00.660',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [44.0, 47.0]},
#   'duration': 0.093,
#   'id': 'b423c91e-3519-4a94-920a-1532d185b3cd',
#   'index': 8,
#   'location': [45.0, 46.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1528310a-ada1-4630-9a9a-42b504f00c7b',
#    '685a0e1a-1036-4a2e-9425-6fd9ef7c7f7a',
#    'f5926997-41d5-486c-89bc-5a9ae4c28dbc'],
#   'second': 0,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:00.660',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.626,
#   'id': 'f5926997-41d5-486c-89bc-5a9ae4c28dbc',
#   'index': 9,
#   'location': [44.0, 47.0],
#   'minute': 0,
#   'pass': {'angle': -1.8925469,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [35.0, 20.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 28.460499,
#    'recipient': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1528310a-ada1-4630-9a9a-42b504f00c7b',
#    'ea77e2e2-4f78-44bc-b003-d13ccd07b5f7'],
#   'second': 0,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:00.753',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': 'ea77e2e2-4f78-44bc-b003-d13ccd07b5f7',
#   'index': 10,
#   'location': [35.0, 20.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1528310a-ada1-4630-9a9a-42b504f00c7b',
#    'f5926997-41d5-486c-89bc-5a9ae4c28dbc'],
#   'second': 2,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:02.379',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [37.0, 16.0]},
#   'duration': 1.241,
#   'id': 'df4ce143-11d3-4664-8287-fa8a1865bf0e',
#   'index': 11,
#   'location': [35.0, 20.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1360fbd8-598c-4790-9ec6-eff2ffba99c0',
#    '1528310a-ada1-4630-9a9a-42b504f00c7b',
#    'ea77e2e2-4f78-44bc-b003-d13ccd07b5f7'],
#   'second': 2,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:02.379',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.04,
#   'id': '1360fbd8-598c-4790-9ec6-eff2ffba99c0',
#   'index': 12,
#   'location': [37.0, 16.0],
#   'minute': 0,
#   'pass': {'angle': 0.3366748,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [57.0, 23.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 21.189621,
#    'recipient': {'id': 5237, 'name': 'Hakim Ziyech'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1528310a-ada1-4630-9a9a-42b504f00c7b',
#    'd0e30d03-f011-4663-8b59-f37c3114eb00'],
#   'second': 3,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:03.620',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': 'd0e30d03-f011-4663-8b59-f37c3114eb00',
#   'index': 13,
#   'location': [57.0, 23.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['1360fbd8-598c-4790-9ec6-eff2ffba99c0'],
#   'second': 4,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:04.660',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [50.0, 26.0]},
#   'duration': 1.2,
#   'id': 'aed91778-86c9-4701-8bf0-1c66e30253be',
#   'index': 14,
#   'location': [57.0, 23.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['d0e30d03-f011-4663-8b59-f37c3114eb00',
#    'e6a518d9-bfb8-4843-a69b-dbc68a6dc810'],
#   'second': 4,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:04.660',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.96,
#   'id': 'e6a518d9-bfb8-4843-a69b-dbc68a6dc810',
#   'index': 15,
#   'location': [50.0, 26.0],
#   'minute': 0,
#   'pass': {'angle': -1.4056476,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [54.0, 2.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 24.33105,
#    'recipient': {'id': 5245, 'name': 'Achraf Hakimi Mouh'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['7ce8f61c-3047-4b86-b8e1-b4a128bf757d'],
#   'second': 5,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:05.860',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 3.746,
#   'id': '61de43cc-fcce-484a-928f-4d9984212ab3',
#   'index': 16,
#   'location': [94.0, 64.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0a04bd5c-392d-4ea5-b146-547aeef5ed56',
#    '62667218-7a0b-4fd4-acb7-4a06bce7481f',
#    '67a95d92-2f5d-48f9-8452-184f85d29720',
#    '7ce8f61c-3047-4b86-b8e1-b4a128bf757d',
#    'fd360c6b-9601-4256-9a63-ffc176243abd'],
#   'second': 5,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:05.993',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '7ce8f61c-3047-4b86-b8e1-b4a128bf757d',
#   'index': 17,
#   'location': [54.0, 2.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['61de43cc-fcce-484a-928f-4d9984212ab3',
#    'e6a518d9-bfb8-4843-a69b-dbc68a6dc810'],
#   'second': 6,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:06.820',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [51.0, 1.0]},
#   'duration': 0.92,
#   'id': '62667218-7a0b-4fd4-acb7-4a06bce7481f',
#   'index': 18,
#   'location': [54.0, 2.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['61de43cc-fcce-484a-928f-4d9984212ab3',
#    '67a95d92-2f5d-48f9-8452-184f85d29720',
#    '7ce8f61c-3047-4b86-b8e1-b4a128bf757d'],
#   'second': 6,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:06.820',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.68,
#   'id': '67a95d92-2f5d-48f9-8452-184f85d29720',
#   'index': 19,
#   'location': [51.0, 1.0],
#   'minute': 0,
#   'pass': {'angle': 2.8430936,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [25.0, 9.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 27.202942,
#    'recipient': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0a04bd5c-392d-4ea5-b146-547aeef5ed56',
#    '61de43cc-fcce-484a-928f-4d9984212ab3'],
#   'second': 7,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:07.740',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '0a04bd5c-392d-4ea5-b146-547aeef5ed56',
#   'index': 20,
#   'location': [25.0, 9.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['61de43cc-fcce-484a-928f-4d9984212ab3',
#    '67a95d92-2f5d-48f9-8452-184f85d29720'],
#   'second': 9,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:09.420',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [25.0, 9.0]},
#   'duration': 1.2,
#   'id': 'fd360c6b-9601-4256-9a63-ffc176243abd',
#   'index': 21,
#   'location': [25.0, 9.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0a04bd5c-392d-4ea5-b146-547aeef5ed56',
#    '61de43cc-fcce-484a-928f-4d9984212ab3',
#    '876e43d8-710d-47b7-8df5-df3ed1333ad4'],
#   'second': 9,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:09.420',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.0,
#   'id': '876e43d8-710d-47b7-8df5-df3ed1333ad4',
#   'index': 22,
#   'location': [25.0, 9.0],
#   'minute': 0,
#   'pass': {'angle': 0.2730087,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [50.0, 16.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 25.96151,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5232, 'name': 'Mbark Boussoufa'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['54107bf3-0191-4a3c-a3b2-4ec4b7f07fc1',
#    'c5a290c3-188b-4a67-bedd-9676ce06d5d0'],
#   'second': 10,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:10.620',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 0.946,
#   'id': '958765dd-1a3e-418f-93b0-ef973131c10b',
#   'index': 23,
#   'location': [94.0, 73.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 4367, 'name': 'Gonçalo Manuel Ganchinho Guedes'},
#   'position': {'id': 22, 'name': 'Right Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'second': 10,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:10.673',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '54107bf3-0191-4a3c-a3b2-4ec4b7f07fc1',
#   'index': 24,
#   'location': [56.0, 21.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['876e43d8-710d-47b7-8df5-df3ed1333ad4'],
#   'second': 11,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:11.620',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.52,
#   'id': 'c5a290c3-188b-4a67-bedd-9676ce06d5d0',
#   'index': 25,
#   'location': [71.0, 65.0],
#   'minute': 0,
#   'pass': {'angle': 0.30288488,
#    'body_part': {'id': 37, 'name': 'Head'},
#    'end_location': [87.0, 70.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 16.763054,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 4367, 'name': 'Gonçalo Manuel Ganchinho Guedes'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['2f5705f5-878a-4fe4-a069-01ff0e12da0a',
#    '876e43d8-710d-47b7-8df5-df3ed1333ad4',
#    'd3cf66c1-8e42-42a4-a629-9f3198b0c4c6'],
#   'second': 11,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:11.620',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': 'd3cf66c1-8e42-42a4-a629-9f3198b0c4c6',
#   'index': 26,
#   'location': [90.0, 72.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 4367, 'name': 'Gonçalo Manuel Ganchinho Guedes'},
#   'position': {'id': 22, 'name': 'Right Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['c5a290c3-188b-4a67-bedd-9676ce06d5d0'],
#   'second': 13,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:13.140',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'id': '2f5705f5-878a-4fe4-a069-01ff0e12da0a',
#   'index': 27,
#   'interception': {'outcome': {'id': 16, 'name': 'Success In Play'}},
#   'location': [34.0, 11.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['c5a290c3-188b-4a67-bedd-9676ce06d5d0'],
#   'second': 13,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:13.140',
#   'type': {'id': 10, 'name': 'Interception'}},
#  {'duration': 0.813,
#   'id': '47623186-8f79-4b1c-819e-d1bdc50ef26c',
#   'index': 28,
#   'location': [75.0, 62.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['39381f7b-ff56-4847-9ffe-aed304f91481',
#    '7b912618-ffc3-48ea-914e-c6706672a314',
#    'eb1b443e-bc8a-4d34-8fd4-bc2926cb1023'],
#   'second': 15,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:15.300',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': 'eb1b443e-bc8a-4d34-8fd4-bc2926cb1023',
#   'index': 29,
#   'location': [43.0, 21.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['47623186-8f79-4b1c-819e-d1bdc50ef26c'],
#   'second': 15,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:15.380',
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'under_pressure': True},
#  {'carry': {'end_location': [43.0, 21.0]},
#   'duration': 0.6,
#   'id': '39381f7b-ff56-4847-9ffe-aed304f91481',
#   'index': 30,
#   'location': [43.0, 21.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['47623186-8f79-4b1c-819e-d1bdc50ef26c',
#    '7b912618-ffc3-48ea-914e-c6706672a314',
#    'eb1b443e-bc8a-4d34-8fd4-bc2926cb1023'],
#   'second': 15,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:15.380',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.12,
#   'id': '7b912618-ffc3-48ea-914e-c6706672a314',
#   'index': 31,
#   'location': [43.0, 21.0],
#   'minute': 0,
#   'pass': {'angle': 1.5707964,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [43.0, 41.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 20.0,
#    'recipient': {'id': 5242, 'name': 'Younès Belhanda'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['47623186-8f79-4b1c-819e-d1bdc50ef26c',
#    'd463eb71-d85e-40c4-8ed5-02af931de1b3'],
#   'second': 15,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:15.980',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': 'd463eb71-d85e-40c4-8ed5-02af931de1b3',
#   'index': 32,
#   'location': [43.0, 41.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['7b912618-ffc3-48ea-914e-c6706672a314'],
#   'second': 17,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:17.100',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 2.08,
#   'id': '4fd6e5c8-d55d-49df-bd15-c7564199b2f8',
#   'index': 33,
#   'location': [43.0, 41.0],
#   'minute': 0,
#   'pass': {'angle': -2.3086114,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [33.0, 30.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 14.866069,
#    'recipient': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['054919e2-12f9-48a3-93c5-2d1df2be9df6'],
#   'second': 17,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:17.100',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '054919e2-12f9-48a3-93c5-2d1df2be9df6',
#   'index': 34,
#   'location': [33.0, 30.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['4fd6e5c8-d55d-49df-bd15-c7564199b2f8'],
#   'second': 19,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:19.180',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [33.0, 30.0]},
#   'duration': 0.04,
#   'id': 'b7fbbf75-a287-47e6-91b9-9220eed5a199',
#   'index': 35,
#   'location': [33.0, 30.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['054919e2-12f9-48a3-93c5-2d1df2be9df6',
#    'd20d3d59-b75f-4a78-8546-fa144bcfa7c9'],
#   'second': 19,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:19.180',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.68,
#   'id': 'd20d3d59-b75f-4a78-8546-fa144bcfa7c9',
#   'index': 36,
#   'location': [33.0, 30.0],
#   'minute': 0,
#   'pass': {'angle': 0.21293835,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [70.0, 38.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 37.85499,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5726, 'name': 'Khalid Boutaïb'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['34ea5c1d-b9a8-41f9-85c7-4f39bd35921a',
#    '4017ea99-95ca-4a41-b682-9c6713d90071'],
#   'second': 19,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:19.220',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '34ea5c1d-b9a8-41f9-85c7-4f39bd35921a',
#   'index': 37,
#   'location': [67.0, 43.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5726, 'name': 'Khalid Boutaïb'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['d20d3d59-b75f-4a78-8546-fa144bcfa7c9'],
#   'second': 20,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:20.900',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 2.44,
#   'id': '4017ea99-95ca-4a41-b682-9c6713d90071',
#   'index': 38,
#   'location': [51.0, 43.0],
#   'minute': 0,
#   'pass': {'angle': -0.56931317,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [76.0, 27.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 29.681644,
#    'recipient': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 20016, 'name': 'Kléper Laveran Lima Ferreira'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['5d29adeb-7f08-48f6-a3a7-55a6462bdfe3',
#    'd20d3d59-b75f-4a78-8546-fa144bcfa7c9'],
#   'second': 20,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:20.900',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'counterpress': True,
#   'duration': 0.96,
#   'id': '61279e43-bd60-45ce-8451-24c33e34014d',
#   'index': 39,
#   'location': [44.0, 55.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['3f50020d-c507-4b62-a45c-771998d7a04d',
#    '5d29adeb-7f08-48f6-a3a7-55a6462bdfe3',
#    'b4af752c-cf05-4a21-98a4-2bf08e5d45a1'],
#   'second': 23,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:23.260',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '5d29adeb-7f08-48f6-a3a7-55a6462bdfe3',
#   'index': 40,
#   'location': [76.0, 27.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['4017ea99-95ca-4a41-b682-9c6713d90071',
#    '61279e43-bd60-45ce-8451-24c33e34014d'],
#   'second': 23,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:23.340',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [76.0, 29.0]},
#   'duration': 0.213,
#   'id': '3f50020d-c507-4b62-a45c-771998d7a04d',
#   'index': 41,
#   'location': [76.0, 27.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['5d29adeb-7f08-48f6-a3a7-55a6462bdfe3',
#    '61279e43-bd60-45ce-8451-24c33e34014d',
#    'b4af752c-cf05-4a21-98a4-2bf08e5d45a1'],
#   'second': 23,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:23.340',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'id': 'b4af752c-cf05-4a21-98a4-2bf08e5d45a1',
#   'index': 42,
#   'location': [76.0, 29.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['61279e43-bd60-45ce-8451-24c33e34014d'],
#   'second': 23,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:23.553',
#   'type': {'id': 38, 'name': 'Miscontrol'},
#   'under_pressure': True},
#  {'id': '624a7f89-1097-4033-a6bc-f666b56c54f1',
#   'index': 43,
#   'location': [54.0, 57.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'second': 24,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:24.460',
#   'type': {'id': 2, 'name': 'Ball Recovery'}},
#  {'carry': {'end_location': [67.0, 64.0]},
#   'duration': 2.68,
#   'id': '71abed5f-f31f-4f9d-85f8-c3546ca4db54',
#   'index': 44,
#   'location': [54.0, 57.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['624a7f89-1097-4033-a6bc-f666b56c54f1',
#    'cdd89183-f79f-40e0-a538-cc8a51f0faf5'],
#   'second': 24,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:24.460',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.96,
#   'id': 'cdd89183-f79f-40e0-a538-cc8a51f0faf5',
#   'index': 45,
#   'location': [67.0, 64.0],
#   'minute': 0,
#   'pass': {'angle': 1.2924967,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [71.0, 78.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 14.56022,
#    'recipient': {'id': 3302, 'name': 'Nordin Amrabat'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['55a772a1-5d3c-415f-bb35-4874fac05ca0'],
#   'second': 27,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:27.140',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '55a772a1-5d3c-415f-bb35-4874fac05ca0',
#   'index': 46,
#   'location': [71.0, 78.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3302, 'name': 'Nordin Amrabat'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['cdd89183-f79f-40e0-a538-cc8a51f0faf5'],
#   'second': 28,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:28.100',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [115.0, 68.0]},
#   'duration': 4.84,
#   'id': '7b23386d-e169-40db-b5d0-d22de036f918',
#   'index': 47,
#   'location': [71.0, 78.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3302, 'name': 'Nordin Amrabat'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['25e2a640-c055-4ee5-a97f-f90069c46f66',
#    '55a772a1-5d3c-415f-bb35-4874fac05ca0',
#    '855e1b5d-5ebd-4709-aa35-bf489cec9c2e'],
#   'second': 28,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:28.100',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 4.173,
#   'id': '25e2a640-c055-4ee5-a97f-f90069c46f66',
#   'index': 48,
#   'location': [44.0, 12.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5214, 'name': 'William Silva de Carvalho'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['7b23386d-e169-40db-b5d0-d22de036f918'],
#   'second': 28,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:28.540',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.8,
#   'id': '855e1b5d-5ebd-4709-aa35-bf489cec9c2e',
#   'index': 49,
#   'location': [115.0, 68.0],
#   'minute': 0,
#   'pass': {'angle': -1.598567,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'cross': True,
#    'end_location': [114.0, 32.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 36.013885,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5237, 'name': 'Hakim Ziyech'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3302, 'name': 'Nordin Amrabat'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['e3c2caf3-85c4-4e10-a5ff-3db367db6770',
#    'f38929d9-6846-4a8b-8c0d-d90a76f22026'],
#   'second': 32,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:32.940',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': 'e3c2caf3-85c4-4e10-a5ff-3db367db6770',
#   'index': 50,
#   'location': [111.0, 40.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['855e1b5d-5ebd-4709-aa35-bf489cec9c2e'],
#   'second': 34,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:34.740',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'id': 'f38929d9-6846-4a8b-8c0d-d90a76f22026',
#   'index': 51,
#   'location': [7.0, 49.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3329, 'name': 'Cédric Ricardo Alves Soares'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['855e1b5d-5ebd-4709-aa35-bf489cec9c2e'],
#   'second': 34,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:34.740',
#   'type': {'id': 9, 'name': 'Clearance'},
#   'under_pressure': True},
#  {'duration': 2.28,
#   'id': '6d55f97c-fea0-4c83-85d9-0ad4f25ad1bb',
#   'index': 52,
#   'location': [4.0, 72.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3329, 'name': 'Cédric Ricardo Alves Soares'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['718f6aef-aee2-4482-a1e5-121b69491207',
#    '9b715b3b-8d91-4d35-9c9e-5747c47b6a47'],
#   'second': 38,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:00:38.060',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '718f6aef-aee2-4482-a1e5-121b69491207',
#   'index': 53,
#   'location': [115.0, 3.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['6d55f97c-fea0-4c83-85d9-0ad4f25ad1bb'],
#   'second': 39,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:39.860',
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'under_pressure': True},
#  {'carry': {'end_location': [109.0, 3.0]},
#   'duration': 1.04,
#   'id': '9b715b3b-8d91-4d35-9c9e-5747c47b6a47',
#   'index': 54,
#   'location': [115.0, 3.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['6d55f97c-fea0-4c83-85d9-0ad4f25ad1bb',
#    '718f6aef-aee2-4482-a1e5-121b69491207',
#    'cfbee886-4d63-4acd-8156-ec73a591862d'],
#   'second': 39,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:39.860',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.8,
#   'id': 'cfbee886-4d63-4acd-8156-ec73a591862d',
#   'index': 55,
#   'location': [109.0, 3.0],
#   'minute': 0,
#   'pass': {'angle': 2.819842,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [91.0, 9.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 18.973665,
#    'recipient': {'id': 5232, 'name': 'Mbark Boussoufa'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5245, 'name': 'Achraf Hakimi Mouh'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['172c4db1-3e51-4858-934e-46856f2d79cf'],
#   'second': 40,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:40.900',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '172c4db1-3e51-4858-934e-46856f2d79cf',
#   'index': 56,
#   'location': [91.0, 9.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['cfbee886-4d63-4acd-8156-ec73a591862d'],
#   'second': 42,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:42.700',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [94.0, 14.0]},
#   'duration': 2.44,
#   'id': '8be89cc3-6893-48d7-a959-1a7faa888b5c',
#   'index': 57,
#   'location': [91.0, 9.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['172c4db1-3e51-4858-934e-46856f2d79cf',
#    '4c9249d8-66ff-4e6d-8344-06043ecb66b6'],
#   'second': 42,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:42.700',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.8,
#   'id': '4c9249d8-66ff-4e6d-8344-06043ecb66b6',
#   'index': 58,
#   'location': [94.0, 14.0],
#   'minute': 0,
#   'pass': {'angle': 0.4636476,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [100.0, 17.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 6.708204,
#    'recipient': {'id': 5237, 'name': 'Hakim Ziyech'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['88086c36-accc-4720-acff-dd95b9868f67'],
#   'second': 45,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:45.140',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '88086c36-accc-4720-acff-dd95b9868f67',
#   'index': 59,
#   'location': [100.0, 17.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['4c9249d8-66ff-4e6d-8344-06043ecb66b6'],
#   'second': 45,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:45.940',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [100.0, 18.0]},
#   'duration': 0.48,
#   'id': '3dc0b12e-2e94-4a32-a50c-45a3eafb1218',
#   'index': 60,
#   'location': [100.0, 17.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0a53228f-b024-45a2-9ae7-a04ca3dd606b',
#    '88086c36-accc-4720-acff-dd95b9868f67'],
#   'second': 45,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:45.940',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.76,
#   'id': '0a53228f-b024-45a2-9ae7-a04ca3dd606b',
#   'index': 61,
#   'location': [100.0, 18.0],
#   'minute': 0,
#   'pass': {'angle': 1.5707964,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [100.0, 22.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 4.0,
#    'recipient': {'id': 5242, 'name': 'Younès Belhanda'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['c8ab3e07-d694-4727-8e94-ee37e9805c8f'],
#   'second': 46,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:46.420',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'c8ab3e07-d694-4727-8e94-ee37e9805c8f',
#   'index': 62,
#   'location': [100.0, 22.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0a53228f-b024-45a2-9ae7-a04ca3dd606b'],
#   'second': 47,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:47.180',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 0.68,
#   'id': '3ee4c22b-3623-4199-ada3-9aa43c6d5711',
#   'index': 63,
#   'location': [100.0, 22.0],
#   'minute': 0,
#   'pass': {'angle': -0.6435011,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [108.0, 16.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 10.0,
#    'recipient': {'id': 5237, 'name': 'Hakim Ziyech'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['777a1201-415b-4819-b380-79934be1aa87'],
#   'second': 47,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:47.180',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '777a1201-415b-4819-b380-79934be1aa87',
#   'index': 64,
#   'location': [108.0, 16.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['3ee4c22b-3623-4199-ada3-9aa43c6d5711'],
#   'second': 47,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:47.860',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 0.32,
#   'id': 'd1268146-f306-4198-bc99-ddf9692d484d',
#   'index': 65,
#   'location': [108.0, 16.0],
#   'minute': 0,
#   'pass': {'angle': 0.0,
#    'body_part': {'id': 70, 'name': 'Other'},
#    'end_location': [112.0, 16.0],
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'length': 4.0,
#    'recipient': {'id': 5245, 'name': 'Achraf Hakimi Mouh'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5237, 'name': 'Hakim Ziyech'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['d2b13e7f-3227-424f-b949-59604612e4c7'],
#   'second': 47,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:00:47.860',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'd2b13e7f-3227-424f-b949-59604612e4c7',
#   'index': 66,
#   'location': [112.0, 16.0],
#   'minute': 0,
# ...
#   'player': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'possession': 56,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['57dec6df-19da-444a-9b16-629f515ab685',
#    '7b6a7f5a-8a24-47c4-a574-2f2c3510a8a9',
#    'e0c5860a-cc7a-4c04-94bf-82137dd4a4e6'],
#   'second': 14,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:24:14.753',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'counterpress': True,
#   'duration': 0.72,
#   'id': '7b6a7f5a-8a24-47c4-a574-2f2c3510a8a9',
#   'index': 978,
#   'location': [63.0, 72.0],
#   'minute': 24,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 56,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['1359792f-b7a0-424f-afd9-6a8ea946750d'],
#   'second': 15,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:24:15.100',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '54da4607-425e-4923-a525-79e21fb1513b',
#   'index': 979,
#   'location': [69.0, 73.0],
#   'minute': 24,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 56,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['e0c5860a-cc7a-4c04-94bf-82137dd4a4e6'],
#   'second': 16,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:24:16.193',
#   'type': {'id': 22, 'name': 'Foul Committed'}},
#  {'id': 'e0c5860a-cc7a-4c04-94bf-82137dd4a4e6',
#   'index': 980,
#   'location': [52.0, 8.0],
#   'minute': 24,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5207, 'name': 'Cristiano Ronaldo dos Santos Aveiro'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'possession': 56,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['54da4607-425e-4923-a525-79e21fb1513b'],
#   'second': 16,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:24:16.193',
#   'type': {'id': 21, 'name': 'Foul Won'},
#   'under_pressure': True},
#  {'duration': 2.0,
#   'id': '3ac7ebfa-f612-4c5d-97b1-d08d5f173c10',
#   'index': 981,
#   'location': [43.0, 9.0],
#   'minute': 25,
#   'pass': {'angle': -0.05258306,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [81.0, 7.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 38.052597,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'type': {'id': 62, 'name': 'Free Kick'}},
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 3960, 'name': 'José Miguel da Rocha Fonte'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 57,
#   'possession_team': {'id': 780, 'name': 'Portugal'},
#   'related_events': ['0ecc4106-47f9-468e-b49c-94a68b441f2e'],
#   'second': 8,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:25:08.420',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '0ecc4106-47f9-468e-b49c-94a68b441f2e',
#   'index': 982,
#   'location': [40.0, 74.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5727, 'name': 'Nabil Dirar'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['3ac7ebfa-f612-4c5d-97b1-d08d5f173c10'],
#   'second': 10,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:10.420',
#   'type': {'id': 2, 'name': 'Ball Recovery'}},
#  {'carry': {'end_location': [42.0, 78.0]},
#   'duration': 2.24,
#   'id': 'b33a7061-534f-41de-9266-59793b4afc9d',
#   'index': 983,
#   'location': [40.0, 74.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5727, 'name': 'Nabil Dirar'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0ecc4106-47f9-468e-b49c-94a68b441f2e',
#    '2a0498c8-6c0d-4745-816c-b14acb92b90d',
#    '949f3368-96d4-4602-aed9-c2331498d181'],
#   'second': 10,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:10.420',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'counterpress': True,
#   'duration': 0.773,
#   'id': '949f3368-96d4-4602-aed9-c2331498d181',
#   'index': 984,
#   'location': [84.0, 10.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 4367, 'name': 'Gonçalo Manuel Ganchinho Guedes'},
#   'position': {'id': 22, 'name': 'Right Center Forward'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['2a0498c8-6c0d-4745-816c-b14acb92b90d',
#    'b33a7061-534f-41de-9266-59793b4afc9d'],
#   'second': 12,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:25:12.100',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.0,
#   'id': '2a0498c8-6c0d-4745-816c-b14acb92b90d',
#   'index': 985,
#   'location': [42.0, 78.0],
#   'minute': 25,
#   'pass': {'angle': -2.5702553,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [28.0, 69.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 16.643316,
#    'recipient': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'}},
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5727, 'name': 'Nabil Dirar'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['005bb99d-c363-417c-b407-9a8899c25762',
#    '949f3368-96d4-4602-aed9-c2331498d181'],
#   'second': 12,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:12.660',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '005bb99d-c363-417c-b407-9a8899c25762',
#   'index': 986,
#   'location': [28.0, 69.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['2a0498c8-6c0d-4745-816c-b14acb92b90d'],
#   'second': 13,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:13.660',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [28.0, 63.0]},
#   'duration': 2.76,
#   'id': '813ca9b6-bd6a-44ab-8fba-0231c972071e',
#   'index': 987,
#   'location': [28.0, 69.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['005bb99d-c363-417c-b407-9a8899c25762',
#    '9556b4d7-8035-4e16-bf78-ec2f4cc6f9ea'],
#   'second': 13,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:13.660',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.24,
#   'id': '9556b4d7-8035-4e16-bf78-ec2f4cc6f9ea',
#   'index': 988,
#   'location': [28.0, 63.0],
#   'minute': 25,
#   'pass': {'angle': -0.7853982,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [41.0, 50.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 18.384777,
#    'recipient': {'id': 5242, 'name': 'Younès Belhanda'}},
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5244, 'name': 'Medhi Amine El Mouttaqi Benatia'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['3810cea0-231a-4c6f-a678-5bddb345e7e3'],
#   'second': 16,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:16.420',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '3810cea0-231a-4c6f-a678-5bddb345e7e3',
#   'index': 989,
#   'location': [41.0, 50.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['9556b4d7-8035-4e16-bf78-ec2f4cc6f9ea'],
#   'second': 17,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:17.660',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [40.0, 53.0]},
#   'duration': 0.4,
#   'id': 'd4d55ac9-3fa1-46b3-940e-5ec1cc616b7e',
#   'index': 990,
#   'location': [41.0, 50.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0d2cc04f-9003-4dd8-ad8a-6ca8a6c2455b',
#    '286aa27f-7450-4feb-9494-cf5f42f0a5ab',
#    '3810cea0-231a-4c6f-a678-5bddb345e7e3'],
#   'second': 17,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:17.660',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'id': '286aa27f-7450-4feb-9494-cf5f42f0a5ab',
#   'index': 991,
#   'location': [81.0, 28.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['0d2cc04f-9003-4dd8-ad8a-6ca8a6c2455b',
#    'd4d55ac9-3fa1-46b3-940e-5ec1cc616b7e'],
#   'second': 18,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:25:18.060',
#   'type': {'id': 22, 'name': 'Foul Committed'}},
#  {'id': '0d2cc04f-9003-4dd8-ad8a-6ca8a6c2455b',
#   'index': 992,
#   'location': [40.0, 53.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['286aa27f-7450-4feb-9494-cf5f42f0a5ab'],
#   'second': 18,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:18.060',
#   'type': {'id': 21, 'name': 'Foul Won'},
#   'under_pressure': True},
#  {'duration': 0.96,
#   'id': '219ab88e-4245-4ee9-bbe6-9fc399911a41',
#   'index': 993,
#   'location': [79.0, 29.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3168, 'name': 'João Filipe Iria Santos Moutinho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 58,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'second': 18,
#   'team': {'id': 780, 'name': 'Portugal'},
#   'timestamp': '00:25:18.153',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 2.32,
#   'id': 'b53ed8f7-0188-4fe2-8e3f-f5e74e69cfd8',
#   'index': 994,
#   'location': [35.0, 44.0],
#   'minute': 25,
#   'pass': {'angle': -1.6902252,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [32.0, 19.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 25.179358,
#    'recipient': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#    'type': {'id': 62, 'name': 'Free Kick'}},
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5242, 'name': 'Younès Belhanda'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['2a07c006-a900-4209-9aee-59a0e55d15f4'],
#   'second': 21,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:21.540',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '2a07c006-a900-4209-9aee-59a0e55d15f4',
#   'index': 995,
#   'location': [32.0, 19.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['b53ed8f7-0188-4fe2-8e3f-f5e74e69cfd8'],
#   'second': 23,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:23.860',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.28,
#   'id': '85bb2a67-f0a0-4a5a-af85-77946997174b',
#   'index': 996,
#   'location': [32.0, 19.0],
#   'minute': 25,
#   'pass': {'angle': -0.4048918,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [39.0, 16.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 7.615773,
#    'recipient': {'id': 5232, 'name': 'Mbark Boussoufa'}},
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['89310eaf-c355-49f7-95ad-f1679fcc0b66'],
#   'second': 23,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:23.860',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '89310eaf-c355-49f7-95ad-f1679fcc0b66',
#   'index': 997,
#   'location': [39.0, 16.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['85bb2a67-f0a0-4a5a-af85-77946997174b'],
#   'second': 25,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:25.140',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [39.0, 16.0]},
#   'duration': 1.09,
#   'id': '76880a7e-64b8-48e8-95cc-1079ff3a7a17',
#   'index': 998,
#   'location': [39.0, 16.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['24800a2e-f6bb-4745-963d-011cf89c1100',
#    '89310eaf-c355-49f7-95ad-f1679fcc0b66'],
#   'second': 25,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:25.140',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.31,
#   'id': '24800a2e-f6bb-4745-963d-011cf89c1100',
#   'index': 999,
#   'location': [39.0, 16.0],
#   'minute': 25,
#   'pass': {'angle': 2.4227626,
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [31.0, 23.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 10.630146,
#    'recipient': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'}},
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5232, 'name': 'Mbark Boussoufa'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['89cd84f2-d70a-479f-9a12-46a6c07e2e46'],
#   'second': 26,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:26.230',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '89cd84f2-d70a-479f-9a12-46a6c07e2e46',
#   'index': 1000,
#   'location': [31.0, 23.0],
#   'minute': 25,
#   'period': 1,
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'player': {'id': 5221, 'name': 'Manuel Marouan da Costa Trinidade'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 59,
#   'possession_team': {'id': 788, 'name': 'Morocco'},
#   'related_events': ['24800a2e-f6bb-4745-963d-011cf89c1100'],
#   'second': 27,
#   'team': {'id': 788, 'name': 'Morocco'},
#   'timestamp': '00:25:27.540',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  ...]

# %%
df = pd.json_normalize(morpor, sep='_').assign(match_id="7542")
df.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  c3a01e2d-02fe-4d24-b291-8ed6a6d16d51      1       1  00:00:00.000       0
# 1  f6b2184f-73f9-434d-8774-c3b5c77fdd26      2       1  00:00:00.000       0
# 2  cf4ba856-d756-47ec-97b9-32f571b504d1      3       1  00:00:00.000       0
# 3  93e265e9-d68c-4ea6-806b-a2719eb9d188      4       1  00:00:00.000       0
# 4  1528310a-ada1-4630-9a9a-42b504f00c7b      5       1  00:00:00.100       0
#
#    second  possession  duration  type_id    type_name  ...  block_offensive  \
# 0       0           1     2.252       35  Starting XI  ...              NaN
# 1       0           1     0.000       35  Starting XI  ...              NaN
# 2       0           1     7.573       18   Half Start  ...              NaN
# 3       0           1     9.120       18   Half Start  ...              NaN
# 4       0           1     4.400       17     Pressure  ...              NaN
#
#   injury_stoppage_in_chain  foul_committed_advantage foul_won_advantage  \
# 0                      NaN                       NaN                NaN
# 1                      NaN                       NaN                NaN
# 2                      NaN                       NaN                NaN
# 3                      NaN                       NaN                NaN
# 4                      NaN                       NaN                NaN
#
#    substitution_outcome_id substitution_outcome_name  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#    substitution_replacement_id substitution_replacement_name  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   foul_committed_offensive match_id
# 0                      NaN     7542
# 1                      NaN     7542
# 2                      NaN     7542
# 3                      NaN     7542
# 4                      NaN     7542
#
# [5 rows x 107 columns]

# %%
shots = df[df.type_name == 'Shot'].set_index('id')
#shots.head()
shots.columns
# Out:
# Index(['index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'type_id', 'type_name', 'possession_team_id',
#        ...
#        'block_offensive', 'injury_stoppage_in_chain',
#        'foul_committed_advantage', 'foul_won_advantage',
#        'substitution_outcome_id', 'substitution_outcome_name',
#        'substitution_replacement_id', 'substitution_replacement_name',
#        'foul_committed_offensive', 'match_id'],
#       dtype='object', length=106)

# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from matplotlib.patches import Arc

def createPitch(length,width, unity,linecolor): # in meters
    # Code by @JPJ_dejong

    """
    creates a plot in which the 'length' is the length of the pitch (goal to goal).
    And 'width' is the width of the pitch (sideline to sideline). 
    Fill in the unity in meters or in yards.
    """
    #Set unity
    if unity == "meters":
        # Set boundaries
        if length >= 120.5 or width >= 75.5:
            return(str("Field dimensions are too big for meters as unity, didn't you mean yards as unity?\
                       Otherwise the maximum length is 120 meters and the maximum width is 75 meters. Please try again"))
        #Run program if unity and boundaries are accepted
        else:
            #Create figure
            fig=plt.figure()
            #fig.set_size_inches(7, 5)
            ax=fig.add_subplot(1,1,1)
           
            #Pitch Outline & Centre Line
            plt.plot([0,0],[0,width], color=linecolor)
            plt.plot([0,length],[width,width], color=linecolor)
            plt.plot([length,length],[width,0], color=linecolor)
            plt.plot([length,0],[0,0], color=linecolor)
            plt.plot([length/2,length/2],[0,width], color=linecolor)
            
            #Left Penalty Area
            plt.plot([16.5 ,16.5],[(width/2 +16.5),(width/2-16.5)],color=linecolor)
            plt.plot([0,16.5],[(width/2 +16.5),(width/2 +16.5)],color=linecolor)
            plt.plot([16.5,0],[(width/2 -16.5),(width/2 -16.5)],color=linecolor)
            
            #Right Penalty Area
            plt.plot([(length-16.5),length],[(width/2 +16.5),(width/2 +16.5)],color=linecolor)
            plt.plot([(length-16.5), (length-16.5)],[(width/2 +16.5),(width/2-16.5)],color=linecolor)
            plt.plot([(length-16.5),length],[(width/2 -16.5),(width/2 -16.5)],color=linecolor)
            
            #Left 5-meters Box
            plt.plot([0,5.5],[(width/2+7.32/2+5.5),(width/2+7.32/2+5.5)],color=linecolor)
            plt.plot([5.5,5.5],[(width/2+7.32/2+5.5),(width/2-7.32/2-5.5)],color=linecolor)
            plt.plot([5.5,0.5],[(width/2-7.32/2-5.5),(width/2-7.32/2-5.5)],color=linecolor)
            
            #Right 5 -eters Box
            plt.plot([length,length-5.5],[(width/2+7.32/2+5.5),(width/2+7.32/2+5.5)],color=linecolor)
            plt.plot([length-5.5,length-5.5],[(width/2+7.32/2+5.5),width/2-7.32/2-5.5],color=linecolor)
            plt.plot([length-5.5,length],[width/2-7.32/2-5.5,width/2-7.32/2-5.5],color=linecolor)
            
            #Prepare Circles
            centreCircle = plt.Circle((length/2,width/2),9.15,color=linecolor,fill=False)
            centreSpot = plt.Circle((length/2,width/2),0.8,color=linecolor)
            leftPenSpot = plt.Circle((11,width/2),0.8,color=linecolor)
            rightPenSpot = plt.Circle((length-11,width/2),0.8,color=linecolor)
            
            #Draw Circles
            ax.add_patch(centreCircle)
            ax.add_patch(centreSpot)
            ax.add_patch(leftPenSpot)
            ax.add_patch(rightPenSpot)
            
            #Prepare Arcs
            leftArc = Arc((11,width/2),height=18.3,width=18.3,angle=0,theta1=308,theta2=52,color=linecolor)
            rightArc = Arc((length-11,width/2),height=18.3,width=18.3,angle=0,theta1=128,theta2=232,color=linecolor)
            
            #Draw Arcs
            ax.add_patch(leftArc)
            ax.add_patch(rightArc)
            #Axis titles

    #check unity again
    elif unity == "yards":
        #check boundaries again
        if length <= 95:
            return(str("Didn't you mean meters as unity?"))
        elif length >= 131 or width >= 101:
            return(str("Field dimensions are too big. Maximum length is 130, maximum width is 100"))
        #Run program if unity and boundaries are accepted
        else:
            #Create figure
            fig=plt.figure()
            #fig.set_size_inches(7, 5)
            ax=fig.add_subplot(1,1,1)
           
            #Pitch Outline & Centre Line
            plt.plot([0,0],[0,width], color=linecolor)
            plt.plot([0,length],[width,width], color=linecolor)
            plt.plot([length,length],[width,0], color=linecolor)
            plt.plot([length,0],[0,0], color=linecolor)
            plt.plot([length/2,length/2],[0,width], color=linecolor)
            
            #Left Penalty Area
            plt.plot([18 ,18],[(width/2 +18),(width/2-18)],color=linecolor)
            plt.plot([0,18],[(width/2 +18),(width/2 +18)],color=linecolor)
            plt.plot([18,0],[(width/2 -18),(width/2 -18)],color=linecolor)
            
            #Right Penalty Area
            plt.plot([(length-18),length],[(width/2 +18),(width/2 +18)],color=linecolor)
            plt.plot([(length-18), (length-18)],[(width/2 +18),(width/2-18)],color=linecolor)
            plt.plot([(length-18),length],[(width/2 -18),(width/2 -18)],color=linecolor)
            
            #Left 6-yard Box
            plt.plot([0,6],[(width/2+7.32/2+6),(width/2+7.32/2+6)],color=linecolor)
            plt.plot([6,6],[(width/2+7.32/2+6),(width/2-7.32/2-6)],color=linecolor)
            plt.plot([6,0],[(width/2-7.32/2-6),(width/2-7.32/2-6)],color=linecolor)
            
            #Right 6-yard Box
            plt.plot([length,length-6],[(width/2+7.32/2+6),(width/2+7.32/2+6)],color=linecolor)
            plt.plot([length-6,length-6],[(width/2+7.32/2+6),width/2-7.32/2-6],color=linecolor)
            plt.plot([length-6,length],[(width/2-7.32/2-6),width/2-7.32/2-6],color=linecolor)
            
            #Prepare Circles; 10 yards distance. penalty on 12 yards
            centreCircle = plt.Circle((length/2,width/2),10,color=linecolor,fill=False)
            centreSpot = plt.Circle((length/2,width/2),0.8,color=linecolor)
            leftPenSpot = plt.Circle((12,width/2),0.8,color=linecolor)
            rightPenSpot = plt.Circle((length-12,width/2),0.8,color=linecolor)
            
            #Draw Circles
            ax.add_patch(centreCircle)
            ax.add_patch(centreSpot)
            ax.add_patch(leftPenSpot)
            ax.add_patch(rightPenSpot)
            
            #Prepare Arcs
            leftArc = Arc((11,width/2),height=20,width=20,angle=0,theta1=312,theta2=48,color=linecolor)
            rightArc = Arc((length-11,width/2),height=20,width=20,angle=0,theta1=130,theta2=230,color=linecolor)
            
            #Draw Arcs
            ax.add_patch(leftArc)
            ax.add_patch(rightArc)
                
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax


def createPitchOld():
    #Taken from FC Python        
    #Create figure
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)

    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,90], color=linecolor)
    plt.plot([0,130],[90,90], color=linecolor)
    plt.plot([130,130],[90,0], color=linecolor)
    plt.plot([130,0],[0,0], color=linecolor)
    plt.plot([65,65],[0,90], color=linecolor)
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color=linecolor)
    plt.plot([0,16.5],[65,65],color=linecolor)
    plt.plot([16.5,0],[25,25],color=linecolor)
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color=linecolor)
    plt.plot([113.5,113.5],[65,25],color=linecolor)
    plt.plot([113.5,130],[25,25],color=linecolor)
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color=linecolor)
    plt.plot([5.5,5.5],[54,36],color=linecolor)
    plt.plot([5.5,0.5],[36,36],color=linecolor)
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color=linecolor)
    plt.plot([124.5,124.5],[54,36],color=linecolor)
    plt.plot([124.5,130],[36,36],color=linecolor)
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color=linecolor,fill=False)
    centreSpot = plt.Circle((65,45),0.8,color=linecolor)
    leftPenSpot = plt.Circle((11,45),0.8,color=linecolor)
    rightPenSpot = plt.Circle((119,45),0.8,color=linecolor)
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color=linecolor)
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color=linecolor)

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax

def createGoalMouth():
    #Adopted from FC Python
    #Create figure
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)

    linecolor='black'

    #Pitch Outline & Centre Line
    plt.plot([0,65],[0,0], color=linecolor)
    plt.plot([65,65],[50,0], color=linecolor)
    plt.plot([0,0],[50,0], color=linecolor)
    
    #Left Penalty Area
    plt.plot([12.5,52.5],[16.5,16.5],color=linecolor)
    plt.plot([52.5,52.5],[16.5,0],color=linecolor)
    plt.plot([12.5,12.5],[0,16.5],color=linecolor)
    
    #Left 6-yard Box
    plt.plot([41.5,41.5],[5.5,0],color=linecolor)
    plt.plot([23.5,41.5],[5.5,5.5],color=linecolor)
    plt.plot([23.5,23.5],[0,5.5],color=linecolor)
    
    #Goal
    plt.plot([41.5-5.34,41.5-5.34],[-2,0],color=linecolor)
    plt.plot([23.5+5.34,41.5-5.34],[-2,-2],color=linecolor)
    plt.plot([23.5+5.34,23.5+5.34],[0,-2],color=linecolor)
    
    #Prepare Circles
    leftPenSpot = plt.Circle((65/2,11),0.8,color=linecolor)
    
    #Draw Circles
    ax.add_patch(leftPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((32.5,11),height=18.3,width=18.3,angle=0,theta1=38,theta2=142,color=linecolor)
    
    #Draw Arcs
    ax.add_patch(leftArc)
    
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax

pitch_width = 120
pitch_height = 80

fig, ax = createPitch(pitch_width, pitch_height, 'yards', 'gray')

home_team = 'Portugal'
away_team = 'Morocco'

for i, shot in shots.iterrows():
    x = shot['location'][0]
    y = shot['location'][1]
    
    goal = shot['shot_outcome_name']=='Goal'
    team_name = shot['team_name']
    
    circle_size = 2
    circle_size = np.sqrt(shot['shot_statsbomb_xg'] * 15)
    
    if team_name == home_team:
        if goal:
            shot_circle = plt.Circle((x, pitch_height-y), circle_size, color='red')
            plt.text((x+1), pitch_height-y+1, shot['shot_statsbomb_xg'])
            plt.text((x+2), pitch_height-y+2, shot['player_name'])
        else:
            shot_circle = plt.Circle((x, pitch_height-y), circle_size, color='red')
            plt.text((x+1), pitch_height-y+1, shot['shot_statsbomb_xg'])
            #plt.text((x+2), pitch_height-y+2, shot['player_name'])
            shot_circle.set_alpha(.2)
    elif team_name == away_team:
        if goal:
            shot_circle = plt.Circle((pitch_width-x, y), circle_size, color='blue')
            plt.text((pitch_width-x+1), y+1, shot['player_name'])
        else:
            shot_circle = plt.Circle((pitch_width-x, y), circle_size, color='blue')
            plt.text((pitch_width-x+1), y+1, shot['shot_statsbomb_xg'])
            #plt.text((pitch_width-x+2), y+2, shot['player_name'])
            shot_circle.set_alpha(.2)
    
    ax.add_patch(shot_circle)
    
plt.text(5, 75, away_team + ' shots')
plt.text(80, 75, home_team + ' shots')

plt.title('Morocco vs Portugal at 2018 FIFA World Cup')

fig.set_size_inches(20, 14)
fig.savefig('morpor_shots.png', dpi=300) 

plt.show()
